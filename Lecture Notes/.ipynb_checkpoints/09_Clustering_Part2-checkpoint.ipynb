# %% [markdown]
# # Clustering Part 2

# %% [markdown]
# * Data processing and normalization
# * Using the elbow method to identify a good number of clusters
# * Evaluation of clustering with Rand Index and Silhouette scoring
# * Different clustering methods: hierarchical clustering, DBSCAN
#
# Datasets: iris, abalone, winequality-red

# %%
#PID:12
import pandas, seaborn
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler, StandardScaler

tips = pandas.read_csv("../Datasets/tips.csv")


# task: preprocess the data and cluster with kmeans

# %%
abalone = pandas.read_csv('../Datasets/abalone.csv')
abalone.sample()

# %%
abalone.describe().round(2).loc[['count','mean','min','max']]

# %%
abalone.sample()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 3454   F   0.575      0.46   0.165         1.065          0.4985
#
#       Viscera weight  Shell weight  Rings
# 3454          0.2145        0.2815      8

# %%
import seaborn
import warnings
warnings.filterwarnings('ignore')

# %%
seaborn.catplot(data=abalone, x='Sex', y='Rings', kind='box', height=2.5)

# %%
abalone = pandas.read_csv('../Datasets/abalone.csv')

abalone = pandas.get_dummies(abalone, drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler
std_abalone = pandas.DataFrame(
    StandardScaler().fit_transform(abalone),
    columns= abalone.columns
)

# %%
std_abalone.sample()
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 1219 -1.657183 -1.843041 -1.542641     -1.406689       -1.364659
#
#       Viscera weight  Shell weight     Rings     Sex_I     Sex_M
# 1219       -1.355767     -1.069295 -1.220208  1.453451 -0.759488

# %%
from sklearn.cluster import KMeans
len(std_abalone)
# Out:
# 4177

# %% [markdown]
# ### find the elbow!

# %%
xs, ys = [], []
for k in range(2, 50):
    model = KMeans(n_clusters=k, n_init='auto')
    model.fit(std_abalone)
    inertia = model.inertia_
    xs.append(k)
    ys.append(inertia)

seaborn.relplot(x=xs, y=ys, height=3, kind='scatter')

# %% [markdown]
# The elbow is around 15, based on our visual analysis.

# %%
model = KMeans(n_clusters=15)
model.fit(std_abalone)
std_abalone['cluster'] = model.labels_

# %%
std_abalone.sample(5)
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 1661  0.632985  0.626020  0.489780      0.744922        0.915274
# 1194  1.465773  1.180300  1.207105      1.667769        2.230966
# 1426  1.840528  1.633801  1.804876      2.898572        3.591716
# 3855 -0.949313 -0.734483 -0.586208     -0.791797       -0.763135
# 1813  1.091018  1.129911  1.446213      1.465865        1.593396
#
#       Viscera weight  Shell weight     Rings     Sex_I     Sex_M  cluster
# 1661        1.130521      0.177239  0.020571 -0.688018  1.316677        4
# 1194        1.153331      1.154348 -0.289624 -0.688018 -0.759488        6
# 1426        2.421566      2.293112 -0.289624 -0.688018 -0.759488        0
# 3855       -0.872195     -0.745986 -0.599818 -0.688018  1.316677        5
# 1813        1.217199      1.632126 -0.289624 -0.688018 -0.759488        6

# %% [markdown]
# ### How do we compare clusters?

# %% [markdown]
# + Use relplot
# + Pick two variables.
# + Color the clusters (hue)

# %%
seaborn.relplot(data=std_abalone, x='Shucked weight', y='Rings', hue='cluster',
                height=3)

# %%
seaborn.relplot(data=std_abalone, x='Shucked weight', y='Rings', col='cluster', col_wrap=4,
                hue='cluster',
                height=3)
