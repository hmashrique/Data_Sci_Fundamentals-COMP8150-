# %% [markdown]
# # Dataframe Transformation

# %% [markdown]
# * Query
# * Transformation: new columns, df.apply(row_processor, axis=1)

# %%
import pandas
iris = pandas.read_csv('../Datasets/iris.csv')

# %%
iris.sample(5)

# %% [markdown]
# Task: Select all iris flowers with petal lengths within 5% of the largest.

# %% [markdown]
# + find the largest petal length
# + define a threshold
# + select data that exceeds this threshold

# %%
largest_pl = iris['PetalLength'].max()
threshold = largest_pl * 0.95
Q = (iris['PetalLength'] >= threshold)

# %%
data = iris[Q]
data

# %% [markdown]
# ---

# %%
#PID:5
#
#  1. calculate tip percentage (tip/total_bill)
#  2. select customers that tip more than average.
#
#

import pandas
tips = pandas.read_csv('../Datasets/tips.csv')
tips['tip_perc'] = tips['tip']/tips['total_bill']
Q = (tips['tip_perc'] > tips['tip_perc'].mean())
data = tips[Q]
data
# Out:
#      total_bill   tip   sex smoker  day    time  size  tip_perc
# 2         21.01  3.50  Male     No  Sun  Dinner     3  0.166587
# 5         25.29  4.71  Male     No  Sun  Dinner     4  0.186240
# 6          8.77  2.00  Male     No  Sun  Dinner     2  0.228050
# 9         14.78  3.23  Male     No  Sun  Dinner     2  0.218539
# 10        10.27  1.71  Male     No  Sun  Dinner     2  0.166504
# ..          ...   ...   ...    ...  ...     ...   ...       ...
# 228       13.28  2.72  Male     No  Sat  Dinner     2  0.204819
# 231       15.69  3.00  Male    Yes  Sat  Dinner     3  0.191205
# 232       11.61  3.39  Male     No  Sat  Dinner     2  0.291990
# 234       15.53  3.00  Male    Yes  Sat  Dinner     2  0.193175
# 239       29.03  5.92  Male     No  Sat  Dinner     3  0.203927
#
# [107 rows x 8 columns]

# %% [markdown]
# **Task**: identify people who spend a lot of money on their meals but tip very little.

# %% [markdown]
# We need to be more specific on a few things:
# + Spending a lot of money on meals:
#     + With 15% of total bill.
# + Tipping very little:
#     + Within 15% of smallest tip percentage.
#     + Less than average tip percentage.
#
# Steps:
# + Calculate the thresholds.
# + Construct the queries
# + Select data.

# %%
tips['tip_perc'] = tips['tip']/tips['total_bill']
t1 = 0.85 * tips['total_bill'].max()
# t2 = 1.15 * tips['tip_perc'].min()
t2 = tips['tip_perc'].mean()
big_spender = (tips['total_bill'] >= t1)
small_tipper = (tips['tip_perc'] <= t2)
data = tips[ big_spender & small_tipper ]
data
# Out:
#      total_bill   tip     sex smoker  day    time  size  tip_perc
# 59        48.27  6.73    Male     No  Sat  Dinner     4  0.139424
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3  0.056433
# 156       48.17  5.00    Male     No  Sun  Dinner     6  0.103799
# 182       45.35  3.50    Male    Yes  Sun  Dinner     3  0.077178

# %% [markdown]
# ---

# %% [markdown]
# When we create a new column `tip_perc`, we technically transform the original dataframe.

# %% [markdown]
# Task: calculate the area of sepals and petals for each flower.
#
# + Area of sepal = sepal length * sepal width
# + What does `calculate` mean?

# %%
iris['sepal_area'] = iris['SepalLength'] * iris['SepalWidth']
iris['petal_area'] = iris['PetalLength'] * iris['PetalWidth']
iris
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth    Species  sepal_area  \
# 0            5.1         3.5          1.4         0.2     setosa       17.85
# 1            4.9         3.0          1.4         0.2     setosa       14.70
# 2            4.7         3.2          1.3         0.2     setosa       15.04
# 3            4.6         3.1          1.5         0.2     setosa       14.26
# 4            5.0         3.6          1.4         0.2     setosa       18.00
# ..           ...         ...          ...         ...        ...         ...
# 145          6.7         3.0          5.2         2.3  virginica       20.10
# 146          6.3         2.5          5.0         1.9  virginica       15.75
# 147          6.5         3.0          5.2         2.0  virginica       19.50
# 148          6.2         3.4          5.4         2.3  virginica       21.08
# 149          5.9         3.0          5.1         1.8  virginica       17.70
#
#      petal_area
# 0          0.28
# 1          0.28
# 2          0.26
# 3          0.30
# 4          0.28
# ..          ...
# 145       11.96
# 146        9.50
# 147       10.40
# 148       12.42
# 149        9.18
#
# [150 rows x 7 columns]

# %% [markdown]
# Task: categorize flowers into small, medium, and large sizes, based on sepal area.
#
# Problem formulation:
# + small: less than 1 std of the mean.
# + medium: within 1 std of the mean.
# + large: above 1 std of the mean.

# %%
t1 = iris['sepal_area'].mean() - iris['sepal_area'].std()
t2 = iris['sepal_area'].mean() + iris['sepal_area'].std()

# %%
def row_processor(row):
    value = row['sepal_area']
    if value < t1:
        size = 'small'
    elif value > t2:
        size = 'large'
    else:
        size = 'medium'
    return size

# %%
iris['size'] = iris.apply(row_processor, axis=1)

# %%
iris['size'].value_counts()
# Out:
# size
# medium    103
# small      24
# large      23
# Name: count, dtype: int64

# %% [markdown]
# Exercise: identify and save customers who spend big and tip well.

# %% [markdown]
# Formulate:
# + Class A = people who spend more than average on bill, and tip more than average.

# %%
import pandas

def row_processor2(row):
    if (row['total_bill'] > average_total_bill) and (row['tip_perc'] > average_tip_perc):
        return True
    else:
        return False
    
tips = pandas.read_csv('../Datasets/tips.csv')
tips['tip_perc'] = tips['tip']/tips['total_bill']

average_total_bill = tips['total_bill'].mean()
average_tip_perc = tips['tip_perc'].mean()

tips['class_A'] = tips.apply(row_processor2, axis=1)

# %%
tips[ tips['class_A']==True ]
# Out:
#      total_bill    tip     sex smoker   day    time  size  tip_perc  class_A
# 2         21.01   3.50    Male     No   Sun  Dinner     3  0.166587     True
# 5         25.29   4.71    Male     No   Sun  Dinner     4  0.186240     True
# 15        21.58   3.92    Male     No   Sun  Dinner     2  0.181650     True
# 19        20.65   3.35    Male     No   Sat  Dinner     3  0.162228     True
# 23        39.42   7.58    Male     No   Sat  Dinner     4  0.192288     True
# 28        21.70   4.30    Male     No   Sat  Dinner     2  0.198157     True
# 44        30.40   5.60    Male     No   Sun  Dinner     4  0.184211     True
# 46        22.23   5.00    Male     No   Sun  Dinner     2  0.224921     True
# 47        32.40   6.00    Male     No   Sun  Dinner     4  0.185185     True
# 54        25.56   4.34    Male     No   Sun  Dinner     4  0.169797     True
# 73        25.28   5.00  Female    Yes   Sat  Dinner     2  0.197785     True
# 88        24.71   5.85    Male     No  Thur   Lunch     2  0.236746     True
# 104       20.92   4.08  Female     No   Sat  Dinner     2  0.195029     True
# 106       20.49   4.06    Male    Yes   Sat  Dinner     2  0.198145     True
# 107       25.21   4.29    Male    Yes   Sat  Dinner     2  0.170171     True
# 116       29.93   5.07    Male     No   Sun  Dinner     4  0.169395     True
# 141       34.30   6.70    Male     No  Thur   Lunch     6  0.195335     True
# 143       27.05   5.00  Female     No  Thur   Lunch     6  0.184843     True
# 155       29.85   5.14  Female     No   Sun  Dinner     5  0.172194     True
# 160       21.50   3.50    Male     No   Sun  Dinner     4  0.162791     True
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  0.196812     True
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2  0.242177     True
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4  0.280535     True
# 185       20.69   5.00    Male     No   Sun  Dinner     5  0.241663     True
# 186       20.90   3.50  Female    Yes   Sun  Dinner     3  0.167464     True
# 189       23.10   4.00    Male    Yes   Sun  Dinner     3  0.173160     True
# 191       19.81   4.19  Female    Yes  Thur   Lunch     2  0.211509     True
# 204       20.53   4.00    Male    Yes  Thur   Lunch     4  0.194837     True
# 211       25.89   5.16    Male    Yes   Sat  Dinner     4  0.199305     True
# 212       48.33   9.00    Male     No   Sat  Dinner     4  0.186220     True
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3  0.230742     True
# 239       29.03   5.92    Male     No   Sat  Dinner     3  0.203927     True
