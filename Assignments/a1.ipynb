# %% [markdown]
# # COMP 7150 Assignment 1
#
# **Deadline**: 02/14/2024 midnight

# %% [markdown]
# NAME: Hasan Mashrique

# %% [markdown]
# **Objective**: This assignment is designed to reinforce your skills in data manipulation and visualization using Pandas and Seaborn with the Auto MPG dataset. By completing this assignment, you will practice techniques including data selection, querying, creating new columns, and visualization.

# %% [markdown]
# ---
# **Note on academic honesty**
#
# All the work you write down and submit in this assignment, must be already discussed in class.
#
# If you use code from other source, you must provide the links to where you use it.
#
# The work must be yours.  Violation receives a zero for the assignment.
#
# ---

# %% [markdown]
# **Submission Requirements**:
#
# * Ensure your code is well-commented to explain your logic and steps.
# * Include markdown cells in your Jupyter Notebook to briefly describe your approach and findings for each question.
# * Turn in a Jupyter notebook to Canvas before the due date
# * Late submissions receive a 10-point deduction.
# * No submission is accepted after the Assignment 1 submission folder is closed.
#
# Each problem is worth 10 points.

# %% [markdown]
# ---
# **Problem 1**
#
# Select and display the rows where the vehicles have 4 cylinders.

# %% [markdown]
# **Solution 1**
#
# 1. First we read the dataset into variable `autompg`.
# 2. From `autompg` dataframe, we select only the `cylinders` having 4 cylinders. Store this result in the variable `cylinder4`.
# 3. View the result stored in `cylinder4`.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas 
autompg= pandas.read_csv("../Datasets/auto-mpg.csv")

# %%
cylinder4= autompg[autompg['cylinders']==4]

cylinder4
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 14   24.0          4         113.0         95    2372          15.0
# 18   27.0          4          97.0         88    2130          14.5
# 19   26.0          4          97.0         46    1835          20.5
# 20   25.0          4         110.0         87    2672          17.5
# 21   24.0          4         107.0         90    2430          14.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                      car name
# 14           70       3         toyota corona mark ii
# ...

# %% [markdown]
# ---
# **Problem 2**
#
# Query and display vehicles with 'mpg' greater than 30 and 'cylinders' equal to 4.

# %% [markdown]
# **Solution 2**
#
# 1. Store the first logic of mpg greater than 30 in variable `Q1`.
# 2. Store the second logic of cylinders equal to 4 in variable `Q2`.
# 3. Apply these filtering logic into the variable `mpgylinders`.
# 4. View the result of `mpgcylinders`.

# %%
Q1= (autompg['mpg']>30)
Q2= (autompg['cylinders']==4)

mpgcylinders= autompg[Q1 & Q2]

mpgcylinders
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 53   31.0          4          71.0         65    1773          19.0
# 54   35.0          4          72.0         69    1613          18.0
# 129  31.0          4          79.0         67    1950          19.0
# 131  32.0          4          71.0         65    1836          21.0
# 144  31.0          4          76.0         52    1649          16.5
# ..    ...        ...           ...        ...     ...           ...
# 390  32.0          4         144.0         96    2665          13.9
# 391  36.0          4         135.0         84    2370          13.0
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin             car name
# 53           71       3  toyota corolla 1200
# 54           71       3          datsun 1200
# ...

# %% [markdown]
# ---
# **Problem 3**
#
# Create a new column named 'weight_kg' by converting 'weight' from pounds to kilograms. (1 pound = 0.453592 kg)

# %% [markdown]
# **Solution 3**
#
# 1. Create a new column in `autompg` dataframe named `weight_kg`.
# 2. In the column, we convert the weight to kg from pounds by multiplying pound with 0.453592.
# 3. Display the dataframe `autompg` with the newly added `weight_kg` column.

# %%
autompg['weight_kg']= autompg['weight']*0.453592

autompg.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 356  32.4          4         108.0         75    2350          16.8
# 297  25.4          5         183.0         77    3530          20.1
# 197  29.0          4          90.0         70    1937          14.2
# 210  19.0          6         156.0        108    2930          15.5
# 64   15.0          8         318.0        150    4135          13.5
#
#      model year  origin            car name    weight_kg
# 356          81       3      toyota corolla  1065.941200
# 297          79       2  mercedes benz 300d  1601.179760
# 197          76       2           vw rabbit   878.607704
# 210          76       3      toyota mark ii  1329.024560
# 64           72       1   plymouth fury iii  1875.602920

# %% [markdown]
# ---
# **Problem 4**
#
# Calculate and display the average 'mpg' for vehicles with 6 cylinders.

# %% [markdown]
# **Solution 4**
#
# 1. Filter out the cars with 6 cylinders from `autompg` and store the result in variable `cylinder6`.
# 2. View sample of the new `cylinder6` data.
# 3. From the new `cylinder6` data, we find the mean the of `mpg` column and round it to 3 decimal places. Store this result in variable `avg_mpg6`.
# 4. View the mean mpg of 6 cylinder cars stored in `avg_mpg6`.

# %%
cylinder6= autompg[autompg['cylinders']==6]

cylinder6.sample(4)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 163  18.0          6         225.0         95    3785          19.0
# 280  21.5          6         231.0        115    3245          15.4
# 37   18.0          6         232.0        100    3288          15.5
# 316  19.1          6         225.0         90    3381          18.7
#
#      model year  origin           car name    weight_kg
# 163          75       1      plymouth fury  1716.845720
# 280          79       1  pontiac lemans v6  1471.906040
# 37           71       1        amc matador  1491.410496
# 316          80       1        dodge aspen  1533.594552

# %%
avg_mpg6= cylinder6['mpg'].mean().round(3)

print("Average mpg for 6 cylinder cars is ", avg_mpg6)
# Out:
# Average mpg for 6 cylinder cars is  19.986

# %% [markdown]
# ---
# **Problem 5**
#
# Use Seaborn to create a histogram of the 'mpg' column. Adjust the bins to improve readability.

# %% [markdown]
# **Solution 5**
#
# 1. Using the seaborn library, we call the histplot on the `mpg` column.
# 2. Change the display with variable bin numbers.

# %%
import seaborn as sns

sns.histplot(data=autompg, x="mpg", bins= 80)
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %% [markdown]
# ---
# **Problem 6**
#
# Visualize the relationship between 'weight_kg' and 'mpg'. Describe the trend.

# %% [markdown]
# **Solution 6**
#
# For this problem, we plot a scatterplot to see the relationship between the variables `weight_kg` and `mpg`.

# %%
sns.relplot(data=autompg, x='weight_kg', y='mpg')

# %% [markdown]
# Looking at the scatterplot, we can observe there is a negative correlation between `weight_kg` and `mpg`. This means as the weight of a car increases, its mpg/fuel efficiency decreases.

# %% [markdown]
# ---
# **Problem 7**
#
# Group the dataset by 'cylinders' and calculate the mean 'mpg' for each group. Display the result.

# %% [markdown]
# **Solution 7**
#
# 1. Use groupby method on the `cylinders` column of `autompg` dataset.
# 2. After groupby, do the mean on the `mpg` column.

# %%
## Mean mpg from cars of each cylinder type.

autompg.groupby("cylinders")[['mpg']].mean()
# Out:
#                  mpg
# cylinders
# 3          20.550000
# 4          29.286765
# 5          27.366667
# 6          19.985714
# 8          14.963107

# %% [markdown]
# ---
# **Problem 8**
#
# Select and display vehicles that are above the 75th percentile in 'mpg' within their respective 'cylinder' category.

# %% [markdown]
# **Solution 8**
#
# 1. Find the 75th percentile value using quantile of the `mpg` column. Store it in `quant`.
# 2. Using `quant`, filter the data from mpg column that are above `quant` value. Store it in `newautos`.
# 4. Use groupby method on the `cylinders` column to group the data by cylinders.
# 5. View the data `newautos`.

# %%
#maxval= autompg['mpg'].max()

# def rowpros(data):
#     if data['mpg']> data['mpg'].quantile(.75):
#         return data

#quant= autompg.groupby('cylinders').apply(rowpros, axis=1)

datacyl = autompg.groupby("cylinders").apply(lambda data: data[data['mpg'] > data['mpg'].quantile(.75)])


datacyl


#quant= autompg.groupby('cylinders').apply(lambda x: x if x['mpg'] > x['mpg'].quantile(.75) else None)
#lambda x: x if x['mpg'] > x['mpg'].quantile(.75)
#print(quant)

# newautos= autompg[autompg['mpg']> quant]

# #newautos
# newautos.groupby("cylinders")
#

#autompg.groupby("cylinders")
# Out:
#                 mpg  cylinders  displacement horsepower  weight  acceleration  \
# cylinders
# 3         334  23.7          3          70.0        100    2420          12.5
# 4         54   35.0          4          72.0         69    1613          18.0
#           218  36.0          4          79.0         58    1825          18.6
#           220  33.5          4          85.0         70    1945          16.8
#           238  33.5          4          98.0         83    2075          15.9
# ...             ...        ...           ...        ...     ...           ...
# 8         291  19.2          8         267.0        125    3605          15.0
#           292  18.5          8         360.0        150    3940          13.0
#           298  23.0          8         350.0        125    3900          17.4
#           300  23.9          8         260.0         90    3420          22.2
#           364  26.6          8         350.0        105    3725          19.0
#
# ...

# %%
autompg.head(5)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name    weight_kg weight_category
# 0       1  chevrolet chevelle malibu  1589.386368          Medium
# 1       1          buick skylark 320  1675.115256          Medium
# 2       1         plymouth satellite  1558.542112          Medium
# 3       1              amc rebel sst  1557.181336          Medium
# 4       1                ford torino  1564.438808          Medium

# %% [markdown]
# ---
# **Problem 9**
#
# Define a custom function to calculate the range (difference between max and min) of 'mpg' values for each 'cylinders' group.
#
# Use this custom function in a `groupby` operation to calculate the 'mpg' range for each 'cylinders' group and display the results.
#
# Display the results, and then analyze whether vehicles with more cylinders tend to have a reduced range of 'mpg' values compared to those with fewer cylinders.

# %% [markdown]
# **Solution 9**
#
# 1. Function `cylinder_range()` is defined.
# 2. Using the function, groupby `autompg` data by `cylinders` and find the `max` and `min` of the `mpg` column data. Store the result in `aggdata`.
# 3. Using  `aggdata`, find the difference of max and min of `mpg` of each `cylinder` type. Store it in `aggdata` creating a new `range` column. Return the `aggdata` as final result.

# %%
def cylinder_range():
    
    aggdata= autompg.groupby('cylinders')[['mpg']].agg(['max','min'])
    
    range= aggdata['mpg']['max'] - aggdata['mpg']['min']
    
    aggdata['range']= range
    
    return aggdata

cylinder_range()
# Out:
#             mpg       range
#             max   min
# cylinders
# 3          23.7  18.0   5.7
# 4          46.6  18.0  28.6
# 5          36.4  20.3  16.1
# 6          38.0  15.0  23.0
# 8          26.6   9.0  17.6

# %% [markdown]
# Looking at the range for each cylinder type, as the cylinders increased, the range of 'mpg' usually increased with it. But for lower cylinder cars, the range was lot smaller.

# %% [markdown]
# ---
# **Problem 10**
#
# Categorizes vehicles into 'Light', 'Medium', and 'Heavy' based on 'weight_kg'. Use the following criteria: 'Light' (< 1500 kg), 'Medium' (1500-2000 kg), 'Heavy' (> 2000 kg). Use the `apply` method to create a new column 'weight_category' based on this custom function.
#
# Analyze the results to determine the relationship between vehicle weight/weight_category and fuel efficiency.

# %% [markdown]
# **Solution 10**
#
# 1. Define custiom function `vehicleCat()`.
# 2. Inside the function, define the weight categories 'Light','Medium' and 'Heavy' based on the `weight_kg` column.
# 3. Create a new column `weight_category` on autompg data and use the `apply()` method on the `vehicleCat` function.
# 4. Display the new `autompg` data.

# %%
def vehicleCat(weight):  # custom function
    if weight<1500:
        size='Light'
    elif weight>2000:
        size='Heavy'
    else:
        size='Medium'
    
    return size

autompg['weight_category']= autompg['weight_kg'].apply(vehicleCat)  # creating new column and applying the custom function vehicleCat.

autompg.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 236  25.5          4         140.0         89    2755          15.8
# 395  32.0          4         135.0         84    2295          11.6
# 60   20.0          4         140.0         90    2408          19.5
# 234  24.5          4         151.0         88    2740          16.0
# 161  16.0          6         250.0        105    3897          18.5
#
#      model year  origin                   car name    weight_kg  \
# 236          77       1        ford mustang ii 2+2  1249.645960
# 395          82       1              dodge rampage  1040.993640
# 60           72       1             chevrolet vega  1092.249536
# 234          77       1      pontiac sunbird coupe  1242.842080
# 161          75       1  chevroelt chevelle malibu  1767.648024
#
#     weight_category
# 236           Light
# 395           Light
# 60            Light
# 234           Light
# 161          Medium

# %% [markdown]
# To find the relationship between vehicle `weight/weight_category` and `fuel efficiency`, lets find the mean `mpg` of each weight category.

# %%
autompg.groupby('weight_category')[['mpg']].mean()
# Out:
#                        mpg
# weight_category
# Heavy            12.846154
# Light            27.365414
# Medium           16.467925

# %% [markdown]
# Looking at the mean mpg for each weight category, we can say that as the weight gets heavier, the fuel efficiency decreases for cars.

# %% [markdown]
# ---
# **Problem 11**
#
# Explore how the origin of vehicles affects their 'mpg'. Calculate the average 'mpg' for vehicles from each origin.
#
# Utilize groupby on the 'origin' column and aggregate using a mean function to find the average 'mpg'.
#
# Discuss the findings to understand if vehicle origin is indicative of fuel efficiency.

# %% [markdown]
# **Solution 11**
#
# 1. `groupby` the autompg data by `origin`. Find the `mean` of the `mpg` column.Store the result in `origindata`.
# 2. Display the `origindata`.

# %%
origindata= autompg.groupby('origin')[['mpg']].mean()
origindata
# Out:
#               mpg
# origin
# 1       20.083534
# 2       27.891429
# 3       30.450633

# %% [markdown]
# To understand the relationship between `origin` and `mpg`, lets plot a barplot.

# %%
sns.barplot(data=origindata, x=origindata.index, y='mpg')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %% [markdown]
# Looking at the barplot, alongside the data, we can stipulate that as origin increases/evolves, the fuel efficiency of the cars increases with it.

# %% [markdown]
# ## Basic code libraries templates for mid-term:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from seaborn import relplot,displot,catplot
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %% [markdown]
# ### Normality Test:

# %%
from scipy.stats import shapiro
from statsmodels.api import qqplot

def test_for_normality(data):
    
    shapiro_test = shapiro(data)
    fig = qqplot(data, line='s')
    print("p value: ", shapiro_test.pvalue)
    
    
 #   return shapiro_test.pvalue
